# %% [markdown]
# <a href="https://colab.research.google.com/github/Claytonsobral27/AnaliseDados/blob/main/%20insights_tabela_campeonato_Brasileiro.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd

# %%
df = pd.read_excel('campeonato_Brasileiro.xlsx')
df
# Out:
#    Unnamed: 0      Times  Partidas_jogadas  Vitorias  Empates  Derrtotas  \
# 0           0  São paulo                10         7        2          1
# 1           2   Flamengo                10         6        2          4
# 2           1  Palmeiras                10         5        2          3
# 3           3     Santos                10         4        1          5
# 4           4   Paysandu                10         3        1          6
#
#    Gols_Pro  Gols_Contra  Pontos
# 0        22           10      23
# 1        16           15      20
# 2        18           12      17
# 3        14           16      13
# 4        10           20      10

# %%
df.dtypes
# Out:
# Unnamed: 0           int64
# Times               object
# Partidas_jogadas     int64
# Vitorias             int64
# Empates              int64
# Derrtotas            int64
# Gols_Pro             int64
# Gols_Contra          int64
# Pontos               int64
# dtype: object

# %%
df.describe()
# Out:
#        Unnamed: 0  Partidas_jogadas  Vitorias   Empates  Derrtotas   Gols_Pro  \
# count    5.000000               5.0  5.000000  5.000000   5.000000   5.000000
# mean     2.000000              10.0  5.000000  1.600000   3.800000  16.000000
# std      1.581139               0.0  1.581139  0.547723   1.923538   4.472136
# min      0.000000              10.0  3.000000  1.000000   1.000000  10.000000
# 25%      1.000000              10.0  4.000000  1.000000   3.000000  14.000000
# 50%      2.000000              10.0  5.000000  2.000000   4.000000  16.000000
# 75%      3.000000              10.0  6.000000  2.000000   5.000000  18.000000
# max      4.000000              10.0  7.000000  2.000000   6.000000  22.000000
#
#        Gols_Contra    Pontos
# count     5.000000   5.00000
# mean     14.600000  16.60000
# std       3.847077   5.22494
# min      10.000000  10.00000
# 25%      12.000000  13.00000
# 50%      15.000000  17.00000
# 75%      16.000000  20.00000
# ...

# %%
df.head(3)
# Out:
#    Unnamed: 0      Times  Partidas_jogadas  Vitorias  Empates  Derrtotas  \
# 0           0  São paulo                10         7        2          1
# 1           2   Flamengo                10         6        2          4
# 2           1  Palmeiras                10         5        2          3
#
#    Gols_Pro  Gols_Contra  Pontos
# 0        22           10      23
# 1        16           15      20
# 2        18           12      17

# %%
df.tail(3)
# Out:
#    Unnamed: 0      Times  Partidas_jogadas  Vitorias  Empates  Derrtotas  \
# 2           1  Palmeiras                10         5        2          3
# 3           3     Santos                10         4        1          5
# 4           4   Paysandu                10         3        1          6
#
#    Gols_Pro  Gols_Contra  Pontos
# 2        18           12      17
# 3        14           16      13
# 4        10           20      10

# %%
#i -Análise de Desempenho por Time
desempenho_info = df[['Times','Pontos', 'Vitorias',]].set_index('Times')
desempenho_info
# Out:
#            Pontos  Vitorias
# Times
# São paulo      23         7
# Flamengo       20         6
# Palmeiras      17         5
# Santos         13         4
# Paysandu       10         3

# %%
df['Saldo_Gols'] = df['Gols_Pro'] - df['Gols_Contra']
df
# Out:
#    Unnamed: 0      Times  Partidas_jogadas  Vitorias  Empates  Derrtotas  \
# 0           0  São paulo                10         7        2          1
# 1           2   Flamengo                10         6        2          4
# 2           1  Palmeiras                10         5        2          3
# 3           3     Santos                10         4        1          5
# 4           4   Paysandu                10         3        1          6
#
#    Gols_Pro  Gols_Contra  Pontos  Saldo_Gols
# 0        22           10      23          12
# 1        16           15      20           1
# 2        18           12      17           6
# 3        14           16      13          -2
# 4        10           20      10         -10

# %%
desempenho_info = df[['Times','Pontos', 'Vitorias','Saldo_Gols','Gols_Pro','Gols_Contra']].set_index('Times')
desempenho_info
# Out:
#            Pontos  Vitorias  Saldo_Gols  Gols_Pro  Gols_Contra
# Times
# São paulo      23         7          12        22           10
# Flamengo       20         6           1        16           15
# Palmeiras      17         5           6        18           12
# Santos         13         4          -2        14           16
# Paysandu       10         3         -10        10           20

# %%
# - TIME COM MÁIS VITÓRIAS E MENOS VITÓRIA

Times_mais_vitorias = df[df['Vitorias'] == df['Vitorias'].max()]
Times_mais_vitorias
# Out:
#    Unnamed: 0      Times  Partidas_jogadas  Vitorias  Empates  Derrtotas  \
# 0           0  São paulo                10         7        2          1
#
#    Gols_Pro  Gols_Contra  Pontos  Saldo_Gols
# 0        22           10      23          12

# %%
# - TIME COM MENOS VITÓRIAS E MENOS VITÓRIA

time_menos_vitorias = df[df['Vitorias']== df['Vitorias'].min()]
time_menos_vitorias
# Out:
#    Unnamed: 0     Times  Partidas_jogadas  Vitorias  Empates  Derrtotas  \
# 4           4  Paysandu                10         3        1          6
#
#    Gols_Pro  Gols_Contra  Pontos  Saldo_Gols
# 4        10           20      10         -10

# %%
# 3 -DISTRIBUIÇÃO DE GOLS PRÓ

df[['Times','Gols_Contra']].value_counts()
# Out:
# Times      Gols_Contra
# Flamengo   15             1
# Palmeiras  12             1
# Paysandu   20             1
# Santos     16             1
# São paulo  10             1
# Name: count, dtype: int64

# %%
#4 - Relação entre gols pró e pontos

correlacao = df['Gols_Pro'].corr(df['Pontos'])
correlacao
# Out:
# np.float64(0.9201150588984628)
