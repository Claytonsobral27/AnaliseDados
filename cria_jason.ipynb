# %% [markdown]
# <a href="https://colab.research.google.com/github/Claytonsobral27/AnaliseDados/blob/main/cria_jason.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd

# %%
df = pd.read_json("//content/dados_receitas.json", encoding="utf-8")
df
# Out:
#                                             receitas
# 0  {'titulo': 'Bolo de Chocolate', 'tempo_preparo...
# 1  {'titulo': 'Salada Caesar', 'tempo_preparo': '...
# 2  {'titulo': 'Pasta ao Pesto', 'tempo_preparo': ...

# %%
df_receitas = pd.json_normalize(df["receitas"],
                                  'ingredientes',
                                ['titulo' , 'tempo_preparo', 'porcoes']


                                )
df_receitas
# Out:
#           ingrediente   quantidade             titulo tempo_preparo porcoes
# 0    Farinha de Trigo    2 xicaras  Bolo de Chocolate    45 minutos       8
# 1              Açúcar     1 xicara  Bolo de Chocolate    45 minutos       8
# 2                 Ovo    3 unidade  Bolo de Chocolate    45 minutos       8
# 3               Leite     1 xicara  Bolo de Chocolate    45 minutos       8
# 4            Manteiga   1/2 xicara  Bolo de Chocolate    45 minutos       8
# 5      Alface roamana     1 cabeça      Salada Caesar    20 minutos       4
# 6            Croutons     1 xícara      Salada Caesar    20 minutos       4
# 7    Queijo parmessão  1/2 unidade      Salada Caesar    20 minutos       4
# 8        Molho caesar  1/4 unidade      Salada Caesar    20 minutos       4
# 9               Massa     1 cabeça     Pasta ao Pesto    30 minutos       2
# 10  Manjericao fresco   1/2 xícara     Pasta ao Pesto    30 minutos       2
# ...
